# %% [markdown]
# ## import numpy, pandas, matplotlib.pyplot

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import read_csv

# %% [markdown]
# ## read the csv file data and store in df array

# %%
df = read_csv('test1.csv')
df
# Out:
#     Outlier1  Outlier2
# 0          3        21
# 1          3        34
# 2         40        57
# 3         10        23
# 4         34        45
# 5         67        45
# 6        100        57
# 7         57        34
# 8         45        44
# 9         23        55
# 10         7        66
# 11        20        33
# 12        26        22
# 13        36        26
# 14        60        60
# 15        35        50
# 16        43        67
# 17        22        54
# 18        27        45
# 19       100        34
# 20        80        39
# 21        45        60
# 22        32        56
# 23        43        33
# 24        22        22
# 25        55        33
# 26        45        44
# 27        45        55
# 28        35        66

# %% [markdown]
# ## display graph

# %%
plt.hist(df.values)
plt.show()

# %% [markdown]
# ## Formula to check outlier

# %%
lower_bound = 0.1 
upper_bound = 0.95
res = df.quantile([lower_bound, upper_bound])
res
# Out:
#       Outlier1  Outlier2
# 0.10       9.4      22.8
# 0.95      92.0      66.0

# %% [markdown]
# ## to show the no outlier

# %%
true_index = (res.loc[lower_bound] < df) & (df < res.loc[upper_bound])
true_index
# Out:
#     Outlier1  Outlier2
# 0      False     False
# 1      False      True
# 2       True      True
# 3       True      True
# 4       True      True
# 5       True      True
# 6      False      True
# 7       True      True
# 8       True      True
# 9       True      True
# 10     False     False
# 11      True      True
# 12      True     False
# 13      True      True
# 14      True      True
# 15      True      True
# 16      True     False
# 17      True      True
# 18      True      True
# 19     False      True
# 20      True      True
# 21      True      True
# 22      True      True
# 23      True      True
# 24      True     False
# 25      True      True
# 26      True      True
# 27      True      True
# 28      True     False

# %% [markdown]
# ## to show the outlier

# %%
false_index = ~true_index
false_index
# Out:
#     Outlier1  Outlier2
# 0       True      True
# 1       True     False
# 2      False     False
# 3      False     False
# 4      False     False
# 5      False     False
# 6       True     False
# 7      False     False
# 8      False     False
# 9      False     False
# 10      True      True
# 11     False     False
# 12     False      True
# 13     False     False
# 14     False     False
# 15     False     False
# 16     False      True
# 17     False     False
# 18     False     False
# 19      True     False
# 20     False     False
# 21     False     False
# 22     False     False
# 23     False     False
# 24     False      True
# 25     False     False
# 26     False     False
# 27     False     False
# 28     False      True

# %% [markdown]
# ## to show the no outlier data

# %%
df.values[true_index.values]
# Out:
# array([34, 40, 57, 10, 23, 34, 45, 67, 45, 57, 57, 34, 45, 44, 23, 55, 20,
#        33, 26, 36, 26, 60, 60, 35, 50, 43, 22, 54, 27, 45, 34, 80, 39, 45,
#        60, 32, 56, 43, 33, 22, 55, 33, 45, 44, 45, 55, 35], dtype=int64)

# %% [markdown]
# ## to find the median

# %%
mid = np.median(df.values[true_index.values])
mid
# Out:
# 36.0

# %% [markdown]
# ## change the outlier data to median value

# %%
df[false_index.values] = mid
mid
# Out:
# 36.0

# %%
df
# Out:
#     Outlier1  Outlier2
# 0          3        21
# 1          3        34
# 2         40        57
# 3         10        23
# 4         34        45
# 5         67        45
# 6        100        57
# 7         57        34
# 8         45        44
# 9         23        55
# 10         7        66
# 11        20        33
# 12        26        22
# 13        36        26
# 14        60        60
# 15        35        50
# 16        43        67
# 17        22        54
# 18        27        45
# 19       100        34
# 20        80        39
# 21        45        60
# 22        32        56
# 23        43        33
# 24        22        22
# 25        55        33
# 26        45        44
# 27        45        55
# 28        35        66
